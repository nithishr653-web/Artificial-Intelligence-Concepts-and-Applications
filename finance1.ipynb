# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/nithishn/Desktop/vs code ml/Finance_Analytics_Dataset.csv")
df.head(10)
# Out:
#    TransactionID        Date AccountType TransactionType    Category  Amount  \
# 0              1  01-01-2023     Savings          Credit   Groceries  120068
# 1              2  02-01-2023     Current           Debit        Rent  145359
# 2              3  03-01-2023      Credit           Debit         EMI  119216
# 3              4  04-01-2023     Savings           Debit         EMI  132038
# 4              5  05-01-2023     Current           Debit        Rent   75523
# 5              6  06-01-2023      Credit          Credit      Salary   71518
# 6              7  07-01-2023     Savings          Credit  Investment   77550
# 7              8  08-01-2023     Current          Credit    Shopping   27040
# 8              9  09-01-2023      Credit          Credit   Groceries  136269
# 9             10  10-01-2023      Credit           Debit        Rent  100660
#
#    Balance  PaymentMode CustomerSegment FraudFlag
# 0    16750          UPI          Retail       Yes
# ...

# %%
df.columns
# Out:
# Index(['TransactionID', 'Date', 'AccountType', 'TransactionType', 'Category',
#        'Amount', 'Balance', 'PaymentMode', 'CustomerSegment', 'FraudFlag'],
#       dtype='object')

# %%
#1 no of transactions in each category count plot
sns.countplot(data=df, x='Category')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
#2 no of transactions in each payment method count plot
sns.countplot(data=df, x='PaymentMode')
# Out:
# <Axes: xlabel='PaymentMode', ylabel='count'>

# %%
#3 show number of transactions by transaction type
sns.countplot(data=df, x='TransactionType')
# Out:
# <Axes: xlabel='TransactionType', ylabel='count'>

# %%
#4 debit vs credit amount comparison bar plot
sns.barplot(data=df, x='TransactionType', y='Amount')
plt.title('Debit vs Credit Amount Comparison')
plt.xlabel('Transaction Type')
plt.ylabel('Amount')
# Out:
# Text(0, 0.5, 'Amount')

# %%
#5 spend by category bar plot

# %%
#6 payment mode usage distribution pie chart
import pandas as pd
payment_mode_counts = df['PaymentMode'].value_counts()
print(payment_mode_counts)
plt.pie(payment_mode_counts, labels=payment_mode_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Payment Mode Usage Distribution')
plt.show()
# Out:
# PaymentMode
# Credit Card    66
# UPI            63
# Cash           60
# Debit Card     57
# Net Banking    54
# Name: count, dtype: int64

# %%
sns.boxplot(data=df, x='Category', y='Amount')
plt.xticks(rotation=45)
plt.title("Transaction Amount by Category")
plt.show()
